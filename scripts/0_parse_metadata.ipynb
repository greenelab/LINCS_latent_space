# %% [markdown]
# # Parse LINCS L1000 metadata
#
# **By Alexandra Lee**
#
# **created January 2019 **
#
# Parse metadata to determine if there are sufficient samples with multiple dose concentrations to train autencoder
#
# Also explore the metadata to determine the breakdown of different cancer types, tissue types, drug types that exist in order to determine the scope of the analysis

# %%
import pandas as pd
import os
import numpy as np

import sys
from cmapPy.pandasGEXpress.parse import parse

randomState = 123
from numpy.random import seed
seed(randomState)

# %%
# Load arguments
metadata_file = os.path.join(os.path.dirname(os.getcwd()), "metadata","GSE92742_Broad_LINCS_inst_info.txt")
cell_file = os.path.join(os.path.dirname(os.getcwd()), "metadata","GSE92742_Broad_LINCS_cell_info.txt")

# %%
# Read sample metadata
metadata = pd.read_table(metadata_file, index_col=None, dtype=str)
metadata.head(10)
# Out:
#                                  inst_id           rna_plate rna_well pert_id  \
# 0  ASG001_MCF7_24H_X1_B7_DUO52HI53LO:F13  ASG001_MCF7_24H_X1      F13    DMSO
# 1  ASG001_MCF7_24H_X1_B7_DUO52HI53LO:G13  ASG001_MCF7_24H_X1      G13    DMSO
# 2  ASG001_MCF7_24H_X1_B7_DUO52HI53LO:I13  ASG001_MCF7_24H_X1      I13    DMSO
# 3  ASG001_MCF7_24H_X1_B7_DUO52HI53LO:K13  ASG001_MCF7_24H_X1      K13    DMSO
# 4  ASG001_MCF7_24H_X1_B7_DUO52HI53LO:N13  ASG001_MCF7_24H_X1      N13    DMSO
# 5  ASG001_MCF7_24H_X1_B7_DUO52HI53LO:P08  ASG001_MCF7_24H_X1      P08    DMSO
# 6  ASG001_MCF7_24H_X1_B7_DUO52HI53LO:P12  ASG001_MCF7_24H_X1      P12    DMSO
# 7  ASG001_MCF7_24H_X1_B7_DUO52HI53LO:P17  ASG001_MCF7_24H_X1      P17    DMSO
# 8  ASG001_MCF7_24H_X1_B7_DUO52HI53LO:P18  ASG001_MCF7_24H_X1      P18    DMSO
# 9  ASG001_MCF7_24H_X1_B7_DUO52HI53LO:P19  ASG001_MCF7_24H_X1      P19    DMSO
#
#   pert_iname    pert_type pert_dose pert_dose_unit pert_time pert_time_unit  \
# 0       DMSO  ctl_vehicle       0.1              %        24              h
# 1       DMSO  ctl_vehicle       0.1              %        24              h
# 2       DMSO  ctl_vehicle       0.1              %        24              h
# 3       DMSO  ctl_vehicle       0.1              %        24              h
# 4       DMSO  ctl_vehicle       0.1              %        24              h
# 5       DMSO  ctl_vehicle       0.1              %        24              h
# 6       DMSO  ctl_vehicle       0.1              %        24              h
# 7       DMSO  ctl_vehicle       0.1              %        24              h
# 8       DMSO  ctl_vehicle       0.1              %        24              h
# 9       DMSO  ctl_vehicle       0.1              %        24              h
#
#   cell_id
# 0    MCF7
# 1    MCF7
# 2    MCF7
# 3    MCF7
# 4    MCF7
# 5    MCF7
# 6    MCF7
# 7    MCF7
# 8    MCF7
# 9    MCF7

# %%
# Read cell line metadata
cell_line_metadata = pd.read_table(cell_file, index_col=None, dtype=str)
cell_line_metadata.head(10)
# Out:
#     cell_id  cell_type base_cell_id precursor_cell_id  \
# 0      A375  cell line         A375              -666
# 1  A375.311  cell line         A375              A375
# 2      A549  cell line         A549              -666
# 3  A549.311  cell line         A549              A549
# 4      A673  cell line         A673              -666
# 5       AGS  cell line          AGS              -666
# 6      BT20  cell line         BT20              -666
# 7      CL34  cell line         CL34              -666
# 8    CORL23  cell line       CORL23              -666
# 9    COV644  cell line       COV644              -666
#
#                                         modification sample_type  \
# 0                                               -666       tumor
# 1  genetically modified to stably express Cas9 pr...       tumor
# 2                                               -666       tumor
# 3  genetically  modified to stably express Cas9 p...       tumor
# 4                                               -666       tumor
# 5                                               -666       tumor
# 6                                               -666       tumor
# 7                                               -666       tumor
# 8                                               -666       tumor
# 9                                               -666       tumor
#
#       primary_site                                           subtype  \
# 0             skin                                malignant melanoma
# 1             skin                                malignant melanoma
# 2             lung             non small cell lung cancer| carcinoma
# 3             lung             non small cell lung cancer| carcinoma
# 4             bone                                   ewing's sarcoma
# 5          stomach                                    adenocarcinoma
# 6           breast                                         carcinoma
# 7  large intestine                         colorectal adenocarcinoma
# 8             lung  non small cell lung cancer| large cell carcinoma
# 9            ovary                    carcinoma| epithelial-mucinous
#
#   original_growth_pattern provider_catalog_id original_source_vendor  \
# 0                adherent            CRL-1619                   ATCC
# 1                adherent            CRL-1619                   ATCC
# 2                adherent             CCL-185                   ATCC
# 3                adherent             CCL-185                   ATCC
# 4                adherent            CRL-1598                   ATCC
# 5                adherent            CRL-1739                   ATCC
# 6                adherent              HTB-19                   ATCC
# 7                adherent                -666                   DSMZ
# 8                adherent            92031919                  ECACC
# 9                adherent                -666                  ECACC
#
#   donor_age donor_sex donor_ethnicity
# 0        54         F            -666
# 1        54         F            -666
# 2        58         M       Caucasian
# 3        58         M       Caucasian
# 4      -666         F            -666
# 5        54         F       Caucasian
# 6        74         F       Caucasian
# 7      -666         F            -666
# 8      -666         M            -666
# 9      -666         F            -666

# %%
# Merge sample metadata and cell line metadata
metadata = metadata.merge(cell_line_metadata, on='cell_id', how='inner')
metadata.head(10)
# Out:
#                                  inst_id           rna_plate rna_well pert_id  \
# 0  ASG001_MCF7_24H_X1_B7_DUO52HI53LO:F13  ASG001_MCF7_24H_X1      F13    DMSO
# 1  ASG001_MCF7_24H_X1_B7_DUO52HI53LO:G13  ASG001_MCF7_24H_X1      G13    DMSO
# 2  ASG001_MCF7_24H_X1_B7_DUO52HI53LO:I13  ASG001_MCF7_24H_X1      I13    DMSO
# 3  ASG001_MCF7_24H_X1_B7_DUO52HI53LO:K13  ASG001_MCF7_24H_X1      K13    DMSO
# 4  ASG001_MCF7_24H_X1_B7_DUO52HI53LO:N13  ASG001_MCF7_24H_X1      N13    DMSO
# 5  ASG001_MCF7_24H_X1_B7_DUO52HI53LO:P08  ASG001_MCF7_24H_X1      P08    DMSO
# 6  ASG001_MCF7_24H_X1_B7_DUO52HI53LO:P12  ASG001_MCF7_24H_X1      P12    DMSO
# 7  ASG001_MCF7_24H_X1_B7_DUO52HI53LO:P17  ASG001_MCF7_24H_X1      P17    DMSO
# 8  ASG001_MCF7_24H_X1_B7_DUO52HI53LO:P18  ASG001_MCF7_24H_X1      P18    DMSO
# 9  ASG001_MCF7_24H_X1_B7_DUO52HI53LO:P19  ASG001_MCF7_24H_X1      P19    DMSO
#
#   pert_iname    pert_type pert_dose pert_dose_unit pert_time pert_time_unit  \
# 0       DMSO  ctl_vehicle       0.1              %        24              h
# 1       DMSO  ctl_vehicle       0.1              %        24              h
# 2       DMSO  ctl_vehicle       0.1              %        24              h
# 3       DMSO  ctl_vehicle       0.1              %        24              h
# 4       DMSO  ctl_vehicle       0.1              %        24              h
# 5       DMSO  ctl_vehicle       0.1              %        24              h
# 6       DMSO  ctl_vehicle       0.1              %        24              h
# 7       DMSO  ctl_vehicle       0.1              %        24              h
# 8       DMSO  ctl_vehicle       0.1              %        24              h
# 9       DMSO  ctl_vehicle       0.1              %        24              h
#
#         ...       modification sample_type primary_site         subtype  \
# 0       ...               -666       tumor       breast  adenocarcinoma
# 1       ...               -666       tumor       breast  adenocarcinoma
# 2       ...               -666       tumor       breast  adenocarcinoma
# 3       ...               -666       tumor       breast  adenocarcinoma
# 4       ...               -666       tumor       breast  adenocarcinoma
# 5       ...               -666       tumor       breast  adenocarcinoma
# 6       ...               -666       tumor       breast  adenocarcinoma
# 7       ...               -666       tumor       breast  adenocarcinoma
# 8       ...               -666       tumor       breast  adenocarcinoma
# 9       ...               -666       tumor       breast  adenocarcinoma
#
#   original_growth_pattern provider_catalog_id original_source_vendor  \
# 0                adherent              HTB-22                   ATCC
# 1                adherent              HTB-22                   ATCC
# 2                adherent              HTB-22                   ATCC
# 3                adherent              HTB-22                   ATCC
# 4                adherent              HTB-22                   ATCC
# 5                adherent              HTB-22                   ATCC
# 6                adherent              HTB-22                   ATCC
# 7                adherent              HTB-22                   ATCC
# 8                adherent              HTB-22                   ATCC
# 9                adherent              HTB-22                   ATCC
#
#   donor_age donor_sex donor_ethnicity
# 0        69         F       Caucasian
# 1        69         F       Caucasian
# 2        69         F       Caucasian
# 3        69         F       Caucasian
# 4        69         F       Caucasian
# 5        69         F       Caucasian
# 6        69         F       Caucasian
# 7        69         F       Caucasian
# 8        69         F       Caucasian
# 9        69         F       Caucasian
#
# [10 rows x 24 columns]

# %%
# Get unique pairs of (drug, cell line)
drug_cell_line_pairs = (
    metadata
    .groupby(['pert_iname', 'pert_type', 'cell_id', 'sample_type', 'primary_site', 'subtype'])
    .size()
    .reset_index()
    .rename(columns={0:'count'})
)

drug_cell_line_pairs.head(5)
# Out:
#                                          pert_iname pert_type  cell_id  \
# 0            (+)-3-(1-propyl-piperidin-3-yl)-phenol    trt_cp  FIBRNPC
# 1            (+)-3-(1-propyl-piperidin-3-yl)-phenol    trt_cp      NEU
# 2            (+)-3-(1-propyl-piperidin-3-yl)-phenol    trt_cp      NPC
# 3  (+/-)-7-hydroxy-2-(N,N-di-n-propylamino)tetralin    trt_cp  FIBRNPC
# 4  (+/-)-7-hydroxy-2-(N,N-di-n-propylamino)tetralin    trt_cp      NEU
#
#   sample_type            primary_site                               subtype  \
# 0      normal                    skin                                  -666
# 1      normal                    -666                                  -666
# 2     primary  central nervous system  normal stem fibroblast-derived iPScs
# 3      normal                    skin                                  -666
# 4      normal                    -666                                  -666
#
#    count
# 0      4
# 1      7
# 2      7
# 3      4
# 4      7

# %%
# %%time
# Filter by dose concentration and time points
num_pairs = drug_cell_line_pairs.shape[0]

multiple_dose_conc = pd.DataFrame(columns=['drug',
                                           'drug type',
                                           'cell line',
                                           'sample type', 
                                           'primary site',
                                           'subtype',
                                           'time point', 
                                           'drug dose',
                                           'count'])

for index, row in drug_cell_line_pairs.iterrows():
    
    # Select samples with specific drug and cell line
    drug, drug_type, cell_line, sample_type, primary_site, cancer_type = row['pert_iname'],row['pert_type'], row['cell_id'], row['sample_type'], row['primary_site'], row['subtype']
    selected_samples = metadata.query('pert_iname == @drug & cell_id == @cell_line', inplace=False)
    
    # Group samples by time point
    timept_counts = (
        selected_samples
        .groupby(['pert_time'])
        .size()
        .reset_index()
        .rename(columns={0:'count'})
    )
    
    # For each time point group determine if multiple dose concentrations were measured
    for timept in timept_counts['pert_time']:
        samples_per_timept = selected_samples.query('pert_time == @timept', inplace=False)   
        
        # Get counts for the different dose concentrations
        dose_conc_counts = (
            samples_per_timept
            .groupby(['pert_dose'])
            .size()
            .reset_index()
            .rename(columns={0:'count'})
        )

        # Keep track of how many samples have multiple dose concentrations
        num_dose_conc = dose_conc_counts.shape[0]
        
        if num_dose_conc > 1:
            
            for index,row in dose_conc_counts.iterrows():
                dose_conc, count = row['pert_dose'], row['count']
                multiple_dose_conc = multiple_dose_conc.append({'drug':drug,
                                                                'drug type': drug_type,
                                                                'cell line':cell_line,
                                                                'sample type': sample_type,
                                                                'primary site': primary_site,
                                                                'subtype': cancer_type,
                                                                'time point': timept,
                                                                'drug dose':dose_conc,
                                                                'count': count},
                                                               ignore_index=True)
# Out:
# CPU times: user 1h 39min 28s, sys: 1.48 s, total: 1h 39min 29s
# Wall time: 1h 39min 29s

# %%
multiple_dose_conc.head(10)
# Out:
#                         drug drug type cell line sample type primary site  \
# 0       1,2-propylene-glycol    trt_cp      HA1E      normal       kidney
# 1       1,2-propylene-glycol    trt_cp      HA1E      normal       kidney
# 2       1,2-propylene-glycol    trt_cp      HA1E      normal       kidney
# 3       1,2-propylene-glycol    trt_cp      HA1E      normal       kidney
# 4  15-delta-prostaglandin-j2    trt_cp      VCAP       tumor     prostate
# 5  15-delta-prostaglandin-j2    trt_cp      VCAP       tumor     prostate
# 6  15-delta-prostaglandin-j2    trt_cp      VCAP       tumor     prostate
# 7  15-delta-prostaglandin-j2    trt_cp      VCAP       tumor     prostate
# 8  15-delta-prostaglandin-j2    trt_cp      VCAP       tumor     prostate
# 9  15-delta-prostaglandin-j2    trt_cp      VCAP       tumor     prostate
#
#          subtype time point drug dose count
# 0  normal kidney         24      10.0     6
# 1  normal kidney         24      19.4    12
# 2  normal kidney          6      10.0     3
# 3  normal kidney          6      19.4     6
# 4      carcinoma         24       1.0     4
# 5      carcinoma         24      10.0    15
# 6      carcinoma         24      20.0     4
# 7      carcinoma         24       5.0     4
# 8      carcinoma         48       1.0     4
# 9      carcinoma         48      20.0     4

# %%
# Get the number of samples that have multiple dose concentrations
multiple_dose_conc['count'].sum()
# Out:
# 230865

# %%
# Get the number of conditions (same drug, cell line, time point with multiple drug dose concentrations)
conditions_count = (
    multiple_dose_conc
    .groupby(['drug', 'drug type', 'cell line', 'sample type', 'primary site', 'subtype', 'time point'])
    .size()
    .reset_index()
    .rename(columns={0:'number of dose concentrations'})
)

conditions_count.shape
# Out:
# (11957, 8)

# %%
conditions_count.head(20)
# Out:
#                          drug drug type cell line sample type  \
# 0        1,2-propylene-glycol    trt_cp      HA1E      normal
# 1        1,2-propylene-glycol    trt_cp      HA1E      normal
# 2   15-delta-prostaglandin-j2    trt_cp      VCAP       tumor
# 3   15-delta-prostaglandin-j2    trt_cp      VCAP       tumor
# 4   15-delta-prostaglandin-j2    trt_cp      VCAP       tumor
# 5           3-amino-benzamide    trt_cp      A549       tumor
# 6           3-amino-benzamide    trt_cp      A549       tumor
# 7           3-amino-benzamide    trt_cp      MCF7       tumor
# 8           3-amino-benzamide    trt_cp      MCF7       tumor
# 9             7-nitroindazole    trt_cp      A375       tumor
# 10            7-nitroindazole    trt_cp      A549       tumor
# 11            7-nitroindazole    trt_cp      A549       tumor
# 12            7-nitroindazole    trt_cp      HA1E      normal
# 13            7-nitroindazole    trt_cp    HCC515      normal
# 14            7-nitroindazole    trt_cp     HEPG2       tumor
# 15            7-nitroindazole    trt_cp      HT29       tumor
# 16            7-nitroindazole    trt_cp      MCF7       tumor
# 17            7-nitroindazole    trt_cp      MCF7       tumor
# 18            7-nitroindazole    trt_cp       PC3       tumor
# 19            7-nitroindazole    trt_cp       PC3       tumor
#
#        primary site                                subtype time point  \
# 0            kidney                          normal kidney         24
# 1            kidney                          normal kidney          6
# 2          prostate                              carcinoma         24
# 3          prostate                              carcinoma         48
# 4          prostate                              carcinoma          6
# 5              lung  non small cell lung cancer| carcinoma         24
# 6              lung  non small cell lung cancer| carcinoma          6
# 7            breast                         adenocarcinoma         24
# 8            breast                         adenocarcinoma          6
# 9              skin                     malignant melanoma          6
# 10             lung  non small cell lung cancer| carcinoma         24
# 11             lung  non small cell lung cancer| carcinoma          6
# 12           kidney                          normal kidney          6
# 13             lung                              carcinoma          6
# 14            liver               hepatocellular carcinoma          6
# 15  large intestine              colorectal adenocarcinoma          6
# 16           breast                         adenocarcinoma         24
# 17           breast                         adenocarcinoma          6
# 18         prostate                         adenocarcinoma         24
# 19         prostate                         adenocarcinoma          6
#
#     number of dose concentrations
# 0                               2
# 1                               2
# 2                               4
# 3                               3
# 4                               4
# 5                              10
# 6                              10
# 7                              10
# 8                              10
# 9                               2
# 10                              2
# 11                              2
# 12                              2
# 13                              2
# 14                              2
# 15                              2
# 16                              2
# 17                              2
# 18                              2
# 19                              2

# %%
# What is the counts for the different subtypes
top_subtype = conditions_count['subtype'].value_counts().index[0]
print(top_subtype)
conditions_count['subtype'].value_counts()
# Out:
# adenocarcinoma
# adenocarcinoma                                          4288
# carcinoma                                               2576
# non small cell lung cancer| carcinoma                    917
# malignant melanoma                                       734
# colorectal adenocarcinoma                                732
# hepatocellular carcinoma                                 701
# epithelial                                               467
# normal kidney                                            314
# normal primary liver                                     260
# kidney epithelial                                        233
# embryonal kidney                                         138
# lymphoma| B-cell| non-hodgkin's| histiocytic              87
# bone marrow                                               81
# acute myelogenous leukemia (AML)| M3 (promyelocytic)      80
# acute lymphoblastic leukemia (ALL)| T-cell                64
# myeloman, haematopoietic,lymphoid                         61
# acute myeloid leukemia (AML)                              45
# acute myelogenous leukemia| M5 (monocytic)                41
# colorectal carcinoma                                      25
# non small cell lung cancer| adenocarcinoma                15
# -666                                                      12
# endometrial adenocarcinoma                                10
# normal stem fibroblast-derived iPScs                      10
# non small cell lung cancer| large cell carcinoma          10
# small cell lung cancer| carcinoma                          9
# ewing's sarcoma                                            5
# endometrial adenocarcinoma| endometrioid carcinoma         5
# mucinous papillary adenocarcinoma                          5
# non small cell lung cancer| adenosquamous carcinoma        5
# non small cell lung cancer| squamous cell carcinoma        5
# carcinoma| clear cell                                      5
# carcinoma| undifferentiated                                5
# acute myelogenous leukemia| promyelocytic                  4
# lymphoma| B-cell| non-hodgkin's| diffuse large cell        4
# carcinoma| epithelial-mucinous                             4
# Name: subtype, dtype: int64

# %%
# What is the counts for the different drugs
top_drug = conditions_count['drug'].value_counts().index[0]
print(top_drug)
conditions_count['drug'].value_counts()
# Out:
# sirolimus
# sirolimus              70
# vorinostat             64
# curcumin               62
# parthenolide           59
# manumycin-a            52
# IL4                    35
# INS                    35
# IFNG                   35
# TNF                    35
# trichostatin-a         33
# IGF2                   31
# GAS6                   30
# IL6                    30
# IGF1                   30
# EGF                    30
# AR                     27
# GDNF                   26
# Y-27632                25
# HGF                    25
# HBEGF                  25
# BTC                    25
# FGF1                   25
# IL1                    24
# tamoxifen              24
# MCSF                   24
# SCF                    24
# KGF                    24
# TGFa                   24
# IFNA                   24
# BNGF                   24
#                        ..
# BRD-K86372560           1
# CMA1                    1
# tetracycline            1
# BRD-K80767319           1
# BRD-K88925856           1
# TPO                     1
# BRD-K62368279           1
# CXCL13                  1
# ATF2                    1
# CXCL11                  1
# BRD-K44289311           1
# tetrachloroethylene     1
# BRD-K24752075           1
# IFNA13                  1
# NFE2L2                  1
# BRD-K38369496           1
# BRD-K95786246           1
# BRD-K81524996           1
# UTS2                    1
# BRD-K77793090           1
# CARTPT                  1
# acetaldehyde            1
# FGF23                   1
# KLK1                    1
# BRD-K30231186           1
# BRD-K07381195           1
# BRD-K63874400           1
# TP53                    1
# BRD-K64609558           1
# CXCL10                  1
# Name: drug, Length: 2482, dtype: int64

# %%
# What is the counts for the different primary tissue site
top_tissue = conditions_count['primary site'].value_counts().index[0]
print(top_tissue)
conditions_count['primary site'].value_counts()
# Out:
# breast
# breast                                4642
# prostate                              2408
# lung                                  1227
# liver                                  961
# large intestine                        757
# skin                                   736
# kidney                                 685
# haematopoietic and lymphoid tissue     325
# bone                                    86
# blood                                   61
# ovary                                   29
# endometrium                             15
# -666                                    10
# central nervous system                  10
# stomach                                  5
# Name: primary site, dtype: int64

# %%
# Filter by the top primary site (tissue types)
conditions_count[conditions_count['primary site'] == top_tissue]['subtype'].value_counts()
# Out:
# adenocarcinoma    3239
# carcinoma          936
# epithelial         467
# Name: subtype, dtype: int64

# %%
conditions_count[(conditions_count['primary site'] == top_tissue) &
                 (conditions_count['subtype'] == top_subtype) &
                 (conditions_count['time point'] == '24')]
# Out:
#                      drug drug type cell line sample type primary site  \
# 7       3-amino-benzamide    trt_cp      MCF7       tumor       breast
# 16        7-nitroindazole    trt_cp      MCF7       tumor       breast
# 35               A-443644    trt_cp      MCF7       tumor       breast
# 37               A-443644    trt_cp  MDAMB231       tumor       breast
# 39               A-443644    trt_cp     SKBR3       tumor       breast
# 49                ABT-737    trt_cp      MCF7       tumor       breast
# 51                ABT-737    trt_cp  MDAMB231       tumor       breast
# 53                ABT-737    trt_cp     SKBR3       tumor       breast
# 70               AG-14361    trt_cp      MCF7       tumor       breast
# 76                 AG-490    trt_cp      MCF7       tumor       breast
# 88      AKT-inhibitor-1-2    trt_cp      MCF7       tumor       breast
# 90      AKT-inhibitor-1-2    trt_cp  MDAMB231       tumor       breast
# 92      AKT-inhibitor-1-2    trt_cp     SKBR3       tumor       breast
# 96       AKT-inhibitor-IV    trt_cp      MCF7       tumor       breast
# 106           ALW-II-38-3    trt_cp      MCF7       tumor       breast
# 108           ALW-II-38-3    trt_cp  MDAMB231       tumor       breast
# 110           ALW-II-38-3    trt_cp     SKBR3       tumor       breast
# 118           ALW-II-49-7    trt_cp      MCF7       tumor       breast
# 120           ALW-II-49-7    trt_cp  MDAMB231       tumor       breast
# 122           ALW-II-49-7    trt_cp     SKBR3       tumor       breast
# 126                AM-580    trt_cp      MCF7       tumor       breast
# 149                    AR   trt_lig      MCF7       tumor       breast
# 153                    AR   trt_lig  MDAMB231       tumor       breast
# 157                    AR   trt_lig     SKBR3       tumor       breast
# 161                    AR    trt_sh      MCF7       tumor       breast
# 171               ARP-101    trt_cp      MCF7       tumor       breast
# 181             AS-601245    trt_cp      MCF7       tumor       breast
# 183             AS-601245    trt_cp  MDAMB231       tumor       breast
# 185             AS-601245    trt_cp     SKBR3       tumor       breast
# 193             AS-605240    trt_cp      MCF7       tumor       breast
# ...                   ...       ...       ...         ...          ...
# 11620          tozasertib    trt_cp  MDAMB231       tumor       breast
# 11624          tozasertib    trt_cp     SKBR3       tumor       breast
# 11632          trametinib    trt_cp      MCF7       tumor       breast
# 11634          trametinib    trt_cp  MDAMB231       tumor       breast
# 11636          trametinib    trt_cp     SKBR3       tumor       breast
# 11644          trequinsin    trt_cp      MCF7       tumor       breast
# 11659           tretinoin    trt_cp      MCF7       tumor       breast
# 11693      trichostatin-a    trt_cp      MCF7       tumor       breast
# 11706         triciribine    trt_cp      MCF7       tumor       breast
# 11709     trifluoperazine    trt_cp      MCF7       tumor       breast
# 11725          triptolide    trt_cp      MCF7       tumor       breast
# 11733        troglitazone    trt_cp      MCF7       tumor       breast
# 11749        tubastatin-a    trt_cp      MCF7       tumor       breast
# 11768  tyrphostin-AG-1478    trt_cp      MCF7       tumor       breast
# 11786        ursolic-acid    trt_cp      MCF7       tumor       breast
# 11794          valdecoxib    trt_cp      MCF7       tumor       breast
# 11800       valproic-acid    trt_cp      MCF7       tumor       breast
# 11815           veliparib    trt_cp      MCF7       tumor       breast
# 11817           veliparib    trt_cp  MDAMB231       tumor       breast
# 11819           veliparib    trt_cp     SKBR3       tumor       breast
# 11831         vemurafenib    trt_cp      MCF7       tumor       breast
# 11833         vemurafenib    trt_cp  MDAMB231       tumor       breast
# 11835         vemurafenib    trt_cp     SKBR3       tumor       breast
# 11841         vinblastine    trt_cp      MCF7       tumor       breast
# 11845         vincristine    trt_cp      MCF7       tumor       breast
# 11874          vorinostat    trt_cp      MCF7       tumor       breast
# 11913        withaferin-a    trt_cp      MCF7       tumor       breast
# 11931          wortmannin    trt_cp      MCF7       tumor       breast
# 11944          zebularine    trt_cp      MCF7       tumor       breast
# 11951            zileuton    trt_cp      MCF7       tumor       breast
#
#               subtype time point  number of dose concentrations
# 7      adenocarcinoma         24                             10
# 16     adenocarcinoma         24                              2
# 35     adenocarcinoma         24                              4
# 37     adenocarcinoma         24                              3
# 39     adenocarcinoma         24                              3
# 49     adenocarcinoma         24                              5
# 51     adenocarcinoma         24                              4
# 53     adenocarcinoma         24                              4
# 70     adenocarcinoma         24                             10
# 76     adenocarcinoma         24                              4
# 88     adenocarcinoma         24                              5
# 90     adenocarcinoma         24                              4
# 92     adenocarcinoma         24                              4
# 96     adenocarcinoma         24                              9
# 106    adenocarcinoma         24                              4
# 108    adenocarcinoma         24                              4
# 110    adenocarcinoma         24                              4
# 118    adenocarcinoma         24                              4
# 120    adenocarcinoma         24                              4
# 122    adenocarcinoma         24                              4
# 126    adenocarcinoma         24                             12
# 149    adenocarcinoma         24                              2
# 153    adenocarcinoma         24                              2
# 157    adenocarcinoma         24                              2
# 161    adenocarcinoma         24                              2
# 171    adenocarcinoma         24                              4
# 181    adenocarcinoma         24                              4
# 183    adenocarcinoma         24                              4
# 185    adenocarcinoma         24                              4
# 193    adenocarcinoma         24                              4
# ...               ...        ...                            ...
# 11620  adenocarcinoma         24                              4
# 11624  adenocarcinoma         24                              4
# 11632  adenocarcinoma         24                              4
# 11634  adenocarcinoma         24                              4
# 11636  adenocarcinoma         24                              4
# 11644  adenocarcinoma         24                              6
# 11659  adenocarcinoma         24                             19
# 11693  adenocarcinoma         24                             27
# 11706  adenocarcinoma         24                              4
# 11709  adenocarcinoma         24                              4
# 11725  adenocarcinoma         24                             10
# 11733  adenocarcinoma         24                              6
# 11749  adenocarcinoma         24                             13
# 11768  adenocarcinoma         24                              2
# 11786  adenocarcinoma         24                              5
# 11794  adenocarcinoma         24                              2
# 11800  adenocarcinoma         24                              4
# 11815  adenocarcinoma         24                             12
# 11817  adenocarcinoma         24                              4
# 11819  adenocarcinoma         24                              4
# 11831  adenocarcinoma         24                              4
# 11833  adenocarcinoma         24                              4
# 11835  adenocarcinoma         24                              4
# 11841  adenocarcinoma         24                              4
# 11845  adenocarcinoma         24                              4
# 11874  adenocarcinoma         24                             44
# 11913  adenocarcinoma         24                             16
# 11931  adenocarcinoma         24                             23
# 11944  adenocarcinoma         24                             10
# 11951  adenocarcinoma         24                              2
#
# [1716 rows x 8 columns]

# %%
conditions_count[(conditions_count['primary site'] == top_tissue) &
                 (conditions_count['subtype'] == top_subtype) &
                 (conditions_count['time point'] == '24')]['drug type'].value_counts()
# Out:
# trt_cp         1614
# trt_lig          87
# trt_sh            9
# trt_oe            5
# ctl_vehicle       1
# Name: drug type, dtype: int64

# %%
multiple_dose_conc[(multiple_dose_conc['primary site'] == top_tissue) &
                 (multiple_dose_conc['subtype'] == top_subtype) &
                 (multiple_dose_conc['time point'] == '24')]
# Out:
#                   drug drug type cell line sample type primary site  \
# 73     7-nitroindazole    trt_cp       PC3       tumor     prostate
# 74     7-nitroindazole    trt_cp       PC3       tumor     prostate
# 261           AG-14361    trt_cp       PC3       tumor     prostate
# 262           AG-14361    trt_cp       PC3       tumor     prostate
# 735       ASN-05257430    trt_cp       PC3       tumor     prostate
# 736       ASN-05257430    trt_cp       PC3       tumor     prostate
# 832            AT-9283    trt_cp       PC3       tumor     prostate
# 833            AT-9283    trt_cp       PC3       tumor     prostate
# 834            AT-9283    trt_cp       PC3       tumor     prostate
# 835            AT-9283    trt_cp       PC3       tumor     prostate
# 836            AT-9283    trt_cp       PC3       tumor     prostate
# 837            AT-9283    trt_cp       PC3       tumor     prostate
# 926         AT1-SHH-09    trt_cp       PC3       tumor     prostate
# 927         AT1-SHH-09    trt_cp       PC3       tumor     prostate
# 928         AT1-SHH-09    trt_cp       PC3       tumor     prostate
# 929         AT1-SHH-09    trt_cp       PC3       tumor     prostate
# 930         AT1-SHH-09    trt_cp       PC3       tumor     prostate
# 931         AT1-SHH-09    trt_cp       PC3       tumor     prostate
# 932         AT1-SHH-09    trt_cp       PC3       tumor     prostate
# 933         AT1-SHH-09    trt_cp       PC3       tumor     prostate
# 1037        AT1-SHH-29    trt_cp       PC3       tumor     prostate
# 1038        AT1-SHH-29    trt_cp       PC3       tumor     prostate
# 1039        AT1-SHH-29    trt_cp       PC3       tumor     prostate
# 1040        AT1-SHH-29    trt_cp       PC3       tumor     prostate
# 1041        AT1-SHH-29    trt_cp       PC3       tumor     prostate
# 1042        AT1-SHH-29    trt_cp       PC3       tumor     prostate
# 1043        AT1-SHH-29    trt_cp       PC3       tumor     prostate
# 1044        AT1-SHH-29    trt_cp       PC3       tumor     prostate
# 1152               AVA    trt_cp       PC3       tumor     prostate
# 1153               AVA    trt_cp       PC3       tumor     prostate
# ...                ...       ...       ...         ...          ...
# 43624     withaferin-a    trt_cp       PC3       tumor     prostate
# 43625     withaferin-a    trt_cp       PC3       tumor     prostate
# 43626     withaferin-a    trt_cp       PC3       tumor     prostate
# 43627     withaferin-a    trt_cp       PC3       tumor     prostate
# 43628     withaferin-a    trt_cp       PC3       tumor     prostate
# 43629     withaferin-a    trt_cp       PC3       tumor     prostate
# 43776       wortmannin    trt_cp       PC3       tumor     prostate
# 43777       wortmannin    trt_cp       PC3       tumor     prostate
# 43778       wortmannin    trt_cp       PC3       tumor     prostate
# 43779       wortmannin    trt_cp       PC3       tumor     prostate
# 43780       wortmannin    trt_cp       PC3       tumor     prostate
# 43781       wortmannin    trt_cp       PC3       tumor     prostate
# 43782       wortmannin    trt_cp       PC3       tumor     prostate
# 43783       wortmannin    trt_cp       PC3       tumor     prostate
# 43784       wortmannin    trt_cp       PC3       tumor     prostate
# 43785       wortmannin    trt_cp       PC3       tumor     prostate
# 43786       wortmannin    trt_cp       PC3       tumor     prostate
# 43787       wortmannin    trt_cp       PC3       tumor     prostate
# 43788       wortmannin    trt_cp       PC3       tumor     prostate
# 43789       wortmannin    trt_cp       PC3       tumor     prostate
# 43790       wortmannin    trt_cp       PC3       tumor     prostate
# 43791       wortmannin    trt_cp       PC3       tumor     prostate
# 43792       wortmannin    trt_cp       PC3       tumor     prostate
# 43793       wortmannin    trt_cp       PC3       tumor     prostate
# 43794       wortmannin    trt_cp       PC3       tumor     prostate
# 43795       wortmannin    trt_cp       PC3       tumor     prostate
# 43796       wortmannin    trt_cp       PC3       tumor     prostate
# 43797       wortmannin    trt_cp       PC3       tumor     prostate
# 43904         zileuton    trt_cp       PC3       tumor     prostate
# 43905         zileuton    trt_cp       PC3       tumor     prostate
#
#               subtype time point            drug dose count
# 73     adenocarcinoma         24                 10.0     5
# 74     adenocarcinoma         24                 80.0     6
# 261    adenocarcinoma         24                 10.0     4
# 262    adenocarcinoma         24                 25.0     6
# 735    adenocarcinoma         24                 10.0     4
# 736    adenocarcinoma         24                 11.1     6
# 832    adenocarcinoma         24      0.0399999991059     3
# 833    adenocarcinoma         24       0.119999997318     3
# 834    adenocarcinoma         24   0.3700000047680001     3
# 835    adenocarcinoma         24   1.1100000143100002     3
# 836    adenocarcinoma         24                 10.0     3
# 837    adenocarcinoma         24        3.32999992371     3
# 926    adenocarcinoma         24       0.159999996424     3
# 927    adenocarcinoma         24             0.160000     9
# 928    adenocarcinoma         24       0.629999995232     3
# 929    adenocarcinoma         24             0.630000     9
# 930    adenocarcinoma         24                 10.0     3
# 931    adenocarcinoma         24            10.000000     8
# 932    adenocarcinoma         24                  2.5     3
# 933    adenocarcinoma         24             2.500000     9
# 1037   adenocarcinoma         24       0.159999996424     2
# 1038   adenocarcinoma         24             0.160000     9
# 1039   adenocarcinoma         24       0.629999995232     3
# 1040   adenocarcinoma         24             0.630000     9
# 1041   adenocarcinoma         24                 10.0     3
# 1042   adenocarcinoma         24            10.000000     9
# 1043   adenocarcinoma         24                  2.5     3
# 1044   adenocarcinoma         24             2.500000     9
# 1152   adenocarcinoma         24      0.0399999991059     3
# 1153   adenocarcinoma         24       0.119999997318     3
# ...               ...        ...                  ...   ...
# 43624  adenocarcinoma         24                  0.2     9
# 43625  adenocarcinoma         24                  0.4    12
# 43626  adenocarcinoma         24                  1.0     9
# 43627  adenocarcinoma         24                 10.0    26
# 43628  adenocarcinoma         24                  2.0    12
# 43629  adenocarcinoma         24                  5.0     9
# 43776  adenocarcinoma         24      0.0399999991059     9
# 43777  adenocarcinoma         24      0.0799999982119     7
# 43778  adenocarcinoma         24                 0.08    12
# 43779  adenocarcinoma         24             0.080000     1
# 43780  adenocarcinoma         24                  0.1     9
# 43781  adenocarcinoma         24       0.119999997318     8
# 43782  adenocarcinoma         24                  0.2     9
# 43783  adenocarcinoma         24  0.37000000476800005     3
# 43784  adenocarcinoma         24   0.3700000047680001     6
# 43785  adenocarcinoma         24       0.370370000601     6
# 43786  adenocarcinoma         24                  0.4    12
# 43787  adenocarcinoma         24             0.400000     1
# 43788  adenocarcinoma         24        0.40000000596     8
# 43789  adenocarcinoma         24                  1.0     9
# 43790  adenocarcinoma         24   1.1100000143100002     9
# 43791  adenocarcinoma         24          1.111109972     6
# 43792  adenocarcinoma         24                 10.0   147
# 43793  adenocarcinoma         24                  2.0    20
# 43794  adenocarcinoma         24             2.000000     1
# 43795  adenocarcinoma         24        3.32999992371     9
# 43796  adenocarcinoma         24   3.3333299160000003     6
# 43797  adenocarcinoma         24                  5.0     9
# 43904  adenocarcinoma         24                 10.0     7
# 43905  adenocarcinoma         24                160.0     6
#
# [2750 rows x 9 columns]

# %%
top_drug = multiple_dose_conc[(multiple_dose_conc['primary site'] == top_tissue) &
                 (multiple_dose_conc['subtype'] == top_subtype) &
                 (multiple_dose_conc['time point'] == '24')]['drug'].value_counts().index[0]
print(top_drug)
# Out:
# vorinostat

# %%
multiple_dose_conc[(multiple_dose_conc['primary site'] == top_tissue) &
                 (multiple_dose_conc['subtype'] == top_subtype) &
                 (multiple_dose_conc['time point'] == '24') &
                  (multiple_dose_conc['drug'] == top_drug)]['count'].sum()
# Out:
# 527

# %%
multiple_dose_conc[(multiple_dose_conc['primary site'] == top_tissue) &
                 (multiple_dose_conc['subtype'] == top_subtype) &
                 (multiple_dose_conc['time point'] == '24')]['count'].sum()
# Out:
# 31219

# %%
conditions_count[conditions_count['primary site'] == top_tissue]['cell line'].value_counts()
# Out:
# VCAP    1364
# PC3     1044
# Name: cell line, dtype: int64

# %%
conditions_count['number of dose concentrations'].max()
# Out:
# 44

# %%
conditions_count.loc[conditions_count['number of dose concentrations'] == 44]
# Out:
#              drug drug type cell line sample type primary site  \
# 11874  vorinostat    trt_cp      MCF7       tumor       breast
# 11887  vorinostat    trt_cp       PC3       tumor     prostate
#
#               subtype time point  number of dose concentrations
# 11874  adenocarcinoma         24                             44
# 11887  adenocarcinoma         24                             44

# %%
# Samples from first condition with 44 doses
drug_name = 'vorinostat'
cell_line_name = 'MCF7'
time_pt = '24'
multiple_dose_conc.loc[(multiple_dose_conc['drug'] == drug_name) &
                       (multiple_dose_conc['cell line'] == cell_line_name) &
                       (multiple_dose_conc['time point'] == time_pt)]['count'].sum()
# Out:
# 527

# %%
drug_name = 'vorinostat'
cell_line_name = 'PC3'
time_pt = '24'
multiple_dose_conc.loc[(multiple_dose_conc['drug'] == drug_name) &
                       (multiple_dose_conc['cell line'] == cell_line_name) &
                       (multiple_dose_conc['time point'] == time_pt)]['count'].sum()
# Out:
# 403

# %%
# Output
dose_file = os.path.join(os.path.dirname(os.getcwd()), "metadata","multiple_dose_conc_counts.txt")
conditions_file = os.path.join(os.path.dirname(os.getcwd()), "metadata","conditions_counts.txt")

multiple_dose_conc.to_csv(dose_file, sep='\t')
conditions_count.to_csv(conditions_file, sep='\t')
